# %%
import pandas as pd
import base64
from openai import OpenAI
import json
from pydantic import BaseModel
import cv2
import numpy as np
import fitz
from PIL import Image
from io import BytesIO
pd.set_option('display.max_columns', None)
from typing import Optional
import matplotlib.pyplot as plt
import json


import pandas as pd
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.styles import Alignment, Border, Side, Font

# %%
def get_contours(image_path):
    # Загрузка изображения
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Инвертируем изображение (пунктирные линии должны быть белыми)
    _, binary = cv2.threshold(image, 150, 255, cv2.THRESH_BINARY_INV)

    # Применяем размытие, чтобы убрать шум
    blurred = cv2.GaussianBlur(binary, (5, 5), 0)

    # Используем морфологию для выделения прямоугольных структур
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
    processed = cv2.morphologyEx(blurred, cv2.MORPH_CLOSE, kernel, iterations=1)

    # Поиск контуров
    contours, _ = cv2.findContours(processed, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key=lambda x: x[0][0][1])
    contours = sorted(contours, key=lambda x: x[0][0][0])
    contours = sorted(contours, key=lambda c: (cv2.boundingRect(c)[1], cv2.boundingRect(c)[0]))

    # Копия изображения для отображения результатов
    output = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

    # Фильтруем и выделяем только прямоугольные блоки
    contours_valid = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        # Условие для фильтрации блоков по размеру
        if 80 < w < 150 and 80 < h < 200:  # Подстраивайте размеры под бланк
            contours_valid.append(contour)
            cv2.rectangle(output, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
    return contours_valid, output

def visualize_row(contours, image_path):
    # Копия изображения для отображения результатов
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    output = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

    # Фильтруем и выделяем только прямоугольные блоки
    contours_valid = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        # Условие для фильтрации блоков по размеру
        if 80 < w < 150 and 80 < h < 200:  # Подстраивайте размеры под бланк
            contours_valid.append(contour)
            cv2.rectangle(output, (x, y), (x + w, y + h), (0, 255, 0), 2)
            # plt.figure(figsize=(10, 10))  # Make the plot bigger
            # plt.imshow(output, cmap='gray')

    return output
    
def get_aligned_pic(template_path, filled_form_path, scale_factor = 0.25):

    # 1. Считываем два изображения
    template = cv2.imread(template_path, 0)   # шаблон (пустой бланк)
    height, width = template.shape
    template = cv2.resize(template, (int(height*scale_factor), int(width*scale_factor)), interpolation=cv2.INTER_AREA)
    filled   = cv2.imread(filled_form_path, 0) # заполненный бланк

    # Приведение заполненного бланка к размеру и разрешению шаблона
    filled = cv2.resize(filled, (template.shape[1], template.shape[0]), interpolation=cv2.INTER_AREA)

    # Нахождение ключевых точек и дескрипторов
    sift = cv2.SIFT_create()
    kp1, des1 = sift.detectAndCompute(template, None)
    kp2, des2 = sift.detectAndCompute(filled, None)

    # Сопоставление точек
    bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)
    matches = bf.match(des1, des2)
    matches = sorted(matches, key=lambda x: x.distance)

    # Используем лучшие сопоставления
    good_matches = matches
    src_pts = np.float32([kp1[m.queryIdx].pt for m in good_matches]).reshape(-1, 1, 2)
    dst_pts = np.float32([kp2[m.trainIdx].pt for m in good_matches]).reshape(-1, 1, 2)

    # Вычисление матрицы гомографии
    matrix, mask = cv2.findHomography(dst_pts, src_pts, cv2.RANSAC, 5.0)

    # Применение перспективного преобразования
    h, w = template.shape
    aligned_image = cv2.warpPerspective(filled, matrix, (w, h))

    aligned_image = cv2.resize(aligned_image, (width, height), interpolation=cv2.INTER_AREA)
    # Сохранение результата
    # cv2.imwrite('aligned_form.jpg', aligned_image)

    return aligned_image

# %%
contours, output = get_contours("../data/template_raw.jpg")

# %%
output1 = visualize_row(contours[2:-2], "../data/template_raw.jpg")
# img = get_aligned_pic("test_pics/valid_format/template.jpg", "test_pics/valid_format/page-1.jpg", scale_factor = 0.3)
# output2 = visualize_row(contours, "aligned_form.jpg")
plt.figure(figsize=(10, 10))  # Make the plot bigger
plt.imshow(output1, cmap='gray')
# plt.imshow(output2, cmap='gray')
plt.show()

# %%
numb_cells_dict = {'date':8,
                   'version':4,
                   'user_id':8,
                   'answer1':9,
                   'correction1':9,
                   'answer2':9,
                   'correction2':9,
                   'answer3':9,
                   'correction3':9,
                   'answer4':9,
                   'correction4':9,
                   'answer5':9,
                   'correction5':9,
                   'answer6':9,
                   'correction6':9,
                   'answer7':9,
                   'correction7':9,
                   'answer8':9,
                   'correction8':9,
                   'answer9':9,
                   'correction9':9,
                   'answer10':9,
                   'correction10':9}

contours, output = get_contours("template_no_head.jpg")
contours = contours[2:-2]


rows_dict = {}
j= 0 
for key, value in numb_cells_dict.items():
    rows_dict[key] = dict() 
    for i in range(value):
        rows_dict[key][i] = contours[j]
        j+=1

# %%
rows_processed_json = {}
for key in rows_dict.keys():
    rows_processed_json[key] = {}
    for i in range(len(rows_dict[key])):
        x, y, w, h = cv2.boundingRect(np.array(rows_dict[key][i]))
        rows_processed_json[key][f'cell{i}'] = dict(x=x, y=y, w=w, h=h, row_name=key, value=None, cell_number=i)

# save to json
with open('rows_data_new_format.json', 'w') as json_file:
    json.dump(rows_processed_json, json_file)

# %%
with open('rows_data_new_format.json', 'r') as json_file:
    rows_json = json.load(json_file)

# %%
rows_processed_json
# Out:
# {'version': {'cell0': {'x': 1590,
#    'y': 843,
#    'w': 102,
#    'h': 106,
#    'row_name': 'version',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 1697,
#    'y': 843,
#    'w': 99,
#    'h': 106,
#    'row_name': 'version',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 1801,
#    'y': 843,
#    'w': 100,
#    'h': 106,
#    'row_name': 'version',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 1906,
#    'y': 843,
#    'w': 102,
#    'h': 106,
#    'row_name': 'version',
#    'value': None,
#    'cell_number': 3}},
#  'date': {'cell0': {'x': 2012,
#    'y': 843,
#    'w': 100,
#    'h': 106,
#    'row_name': 'date',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2117,
#    'y': 843,
#    'w': 100,
#    'h': 106,
#    'row_name': 'date',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2221,
#    'y': 843,
#    'w': 102,
#    'h': 106,
#    'row_name': 'date',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2328,
#    'y': 843,
#    'w': 100,
#    'h': 106,
#    'row_name': 'date',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1093,
#    'y': 846,
#    'w': 91,
#    'h': 98,
#    'row_name': 'date',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1188,
#    'y': 846,
#    'w': 90,
#    'h': 98,
#    'row_name': 'date',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1283,
#    'y': 846,
#    'w': 90,
#    'h': 98,
#    'row_name': 'date',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1377,
#    'y': 846,
#    'w': 91,
#    'h': 98,
#    'row_name': 'date',
#    'value': None,
#    'cell_number': 7}},
#  'user_id': {'cell0': {'x': 2522,
#    'y': 847,
#    'w': 102,
#    'h': 106,
#    'row_name': 'user_id',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2628,
#    'y': 847,
#    'w': 100,
#    'h': 106,
#    'row_name': 'user_id',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2733,
#    'y': 847,
#    'w': 100,
#    'h': 106,
#    'row_name': 'user_id',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2837,
#    'y': 847,
#    'w': 102,
#    'h': 106,
#    'row_name': 'user_id',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2944,
#    'y': 847,
#    'w': 100,
#    'h': 106,
#    'row_name': 'user_id',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 3048,
#    'y': 847,
#    'w': 100,
#    'h': 106,
#    'row_name': 'user_id',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 3153,
#    'y': 847,
#    'w': 102,
#    'h': 106,
#    'row_name': 'user_id',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3259,
#    'y': 847,
#    'w': 100,
#    'h': 106,
#    'row_name': 'user_id',
#    'value': None,
#    'cell_number': 7}},
#  'answer1': {'cell0': {'x': 510,
#    'y': 2300,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 642,
#    'y': 2300,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 2300,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 909,
#    'y': 2300,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1041,
#    'y': 2300,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1176,
#    'y': 2300,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1308,
#    'y': 2300,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1440,
#    'y': 2300,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1576,
#    'y': 2300,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer1',
#    'value': None,
#    'cell_number': 8}},
#  'correction1': {'cell0': {'x': 2072,
#    'y': 2300,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2204,
#    'y': 2300,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 2300,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2472,
#    'y': 2300,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2603,
#    'y': 2300,
#    'w': 130,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2739,
#    'y': 2300,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2871,
#    'y': 2300,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3003,
#    'y': 2300,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3138,
#    'y': 2300,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction1',
#    'value': None,
#    'cell_number': 8}},
#  'answer2': {'cell0': {'x': 510,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 645,
#    'y': 2549,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 913,
#    'y': 2549,
#    'w': 125,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1045,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1180,
#    'y': 2549,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1312,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1447,
#    'y': 2549,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1579,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer2',
#    'value': None,
#    'cell_number': 8}},
#  'correction2': {'cell0': {'x': 2072,
#    'y': 2549,
#    'w': 130,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2208,
#    'y': 2549,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2475,
#    'y': 2549,
#    'w': 126,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2607,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2742,
#    'y': 2549,
#    'w': 126,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2874,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3010,
#    'y': 2549,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3142,
#    'y': 2549,
#    'w': 129,
#    'h': 155,
#    'row_name': 'correction2',
#    'value': None,
#    'cell_number': 8}},
#  'answer3': {'cell0': {'x': 510,
#    'y': 2802,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 642,
#    'y': 2802,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 2802,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 909,
#    'y': 2802,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1041,
#    'y': 2802,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1176,
#    'y': 2802,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1308,
#    'y': 2802,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1440,
#    'y': 2802,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1576,
#    'y': 2802,
#    'w': 125,
#    'h': 155,
#    'row_name': 'answer3',
#    'value': None,
#    'cell_number': 8}},
#  'correction3': {'cell0': {'x': 2072,
#    'y': 2802,
#    'w': 126,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2204,
#    'y': 2802,
#    'w': 129,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 2802,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2472,
#    'y': 2802,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2603,
#    'y': 2802,
#    'w': 130,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2739,
#    'y': 2802,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2871,
#    'y': 2802,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3003,
#    'y': 2802,
#    'w': 129,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3138,
#    'y': 2802,
#    'w': 126,
#    'h': 155,
#    'row_name': 'correction3',
#    'value': None,
#    'cell_number': 8}},
#  'answer4': {'cell0': {'x': 510,
#    'y': 3055,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 642,
#    'y': 3055,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 3055,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 909,
#    'y': 3055,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1041,
#    'y': 3055,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1176,
#    'y': 3055,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1308,
#    'y': 3055,
#    'w': 126,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1440,
#    'y': 3055,
#    'w': 129,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1576,
#    'y': 3055,
#    'w': 125,
#    'h': 155,
#    'row_name': 'answer4',
#    'value': None,
#    'cell_number': 8}},
#  'correction4': {'cell0': {'x': 2072,
#    'y': 3055,
#    'w': 126,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2204,
#    'y': 3055,
#    'w': 129,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 3055,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2472,
#    'y': 3055,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2603,
#    'y': 3055,
#    'w': 130,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2739,
#    'y': 3055,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2871,
#    'y': 3055,
#    'w': 125,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3003,
#    'y': 3055,
#    'w': 129,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3138,
#    'y': 3055,
#    'w': 126,
#    'h': 155,
#    'row_name': 'correction4',
#    'value': None,
#    'cell_number': 8}},
#  'answer5': {'cell0': {'x': 510,
#    'y': 3309,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 642,
#    'y': 3309,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 3309,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 909,
#    'y': 3309,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1041,
#    'y': 3309,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1176,
#    'y': 3309,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1308,
#    'y': 3309,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1440,
#    'y': 3309,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1576,
#    'y': 3309,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer5',
#    'value': None,
#    'cell_number': 8}},
#  'correction5': {'cell0': {'x': 2072,
#    'y': 3309,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2204,
#    'y': 3309,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 3309,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2472,
#    'y': 3309,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2603,
#    'y': 3309,
#    'w': 130,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2739,
#    'y': 3309,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2871,
#    'y': 3309,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3003,
#    'y': 3309,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3138,
#    'y': 3309,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction5',
#    'value': None,
#    'cell_number': 8}},
#  'answer6': {'cell0': {'x': 510,
#    'y': 3562,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 642,
#    'y': 3562,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 3562,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 909,
#    'y': 3562,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1041,
#    'y': 3562,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1176,
#    'y': 3562,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1308,
#    'y': 3562,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1440,
#    'y': 3562,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1576,
#    'y': 3562,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer6',
#    'value': None,
#    'cell_number': 8}},
#  'correction6': {'cell0': {'x': 2072,
#    'y': 3562,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2204,
#    'y': 3562,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 3562,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2472,
#    'y': 3562,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2603,
#    'y': 3562,
#    'w': 130,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2739,
#    'y': 3562,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2871,
#    'y': 3562,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3003,
#    'y': 3562,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3138,
#    'y': 3562,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction6',
#    'value': None,
#    'cell_number': 8}},
#  'answer7': {'cell0': {'x': 510,
#    'y': 3815,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 642,
#    'y': 3815,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 3815,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 909,
#    'y': 3815,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1041,
#    'y': 3815,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1176,
#    'y': 3815,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1308,
#    'y': 3815,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1440,
#    'y': 3815,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1576,
#    'y': 3815,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer7',
#    'value': None,
#    'cell_number': 8}},
#  'correction7': {'cell0': {'x': 2072,
#    'y': 3815,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2204,
#    'y': 3815,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 3815,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2472,
#    'y': 3815,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2603,
#    'y': 3815,
#    'w': 130,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2739,
#    'y': 3815,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2871,
#    'y': 3815,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3003,
#    'y': 3815,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3138,
#    'y': 3815,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction7',
#    'value': None,
#    'cell_number': 8}},
#  'answer8': {'cell0': {'x': 510,
#    'y': 4068,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 642,
#    'y': 4068,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 4068,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 909,
#    'y': 4068,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1041,
#    'y': 4068,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1176,
#    'y': 4068,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1308,
#    'y': 4068,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1440,
#    'y': 4068,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1576,
#    'y': 4068,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer8',
#    'value': None,
#    'cell_number': 8}},
#  'correction8': {'cell0': {'x': 2072,
#    'y': 4068,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2204,
#    'y': 4068,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 4068,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2472,
#    'y': 4068,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2603,
#    'y': 4068,
#    'w': 130,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2739,
#    'y': 4068,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2871,
#    'y': 4068,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3003,
#    'y': 4068,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3138,
#    'y': 4068,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction8',
#    'value': None,
#    'cell_number': 8}},
#  'answer9': {'cell0': {'x': 510,
#    'y': 4321,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 642,
#    'y': 4321,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 777,
#    'y': 4321,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 909,
#    'y': 4321,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1041,
#    'y': 4321,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1176,
#    'y': 4321,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1308,
#    'y': 4321,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1440,
#    'y': 4321,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1576,
#    'y': 4321,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer9',
#    'value': None,
#    'cell_number': 8}},
#  'correction9': {'cell0': {'x': 2072,
#    'y': 4321,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2204,
#    'y': 4321,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2340,
#    'y': 4321,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2472,
#    'y': 4321,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2603,
#    'y': 4321,
#    'w': 130,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2739,
#    'y': 4321,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2871,
#    'y': 4321,
#    'w': 125,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 3003,
#    'y': 4321,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3138,
#    'y': 4321,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction9',
#    'value': None,
#    'cell_number': 8}},
#  'answer10': {'cell0': {'x': 499,
#    'y': 4574,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 635,
#    'y': 4574,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 767,
#    'y': 4574,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 898,
#    'y': 4574,
#    'w': 130,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 1034,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 1166,
#    'y': 4574,
#    'w': 125,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 1298,
#    'y': 4574,
#    'w': 129,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 1433,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 1565,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'answer10',
#    'value': None,
#    'cell_number': 8}},
#  'correction10': {'cell0': {'x': 2062,
#    'y': 4574,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 0},
#   'cell1': {'x': 2197,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 1},
#   'cell2': {'x': 2329,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 2},
#   'cell3': {'x': 2461,
#    'y': 4574,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 3},
#   'cell4': {'x': 2596,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 4},
#   'cell5': {'x': 2728,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 5},
#   'cell6': {'x': 2860,
#    'y': 4574,
#    'w': 129,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 6},
#   'cell7': {'x': 2995,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 7},
#   'cell8': {'x': 3127,
#    'y': 4574,
#    'w': 126,
#    'h': 154,
#    'row_name': 'correction10',
#    'value': None,
#    'cell_number': 8}}}
